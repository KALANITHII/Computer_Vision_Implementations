# %% [markdown]
# "Image Processing with OpenCV in Python"
#
# This notebook showcases fundamental image processing tasks using the OpenCV library in Python. The program begins by reading and displaying an image. It then demonstrates the transformation of a colored image into grayscale. Subsequently, various geometric transformations such as scaling, rotation, affine, Euclidean, and similarity translations are performed to illustrate their impact on the image. Finally, the notebook reads an image from a video source and displays it, providing a comprehensive introduction to essential image processing techniques using OpenCV.

# %%
import cv2

# %%
image = cv2.imread("/content/dog.jpg")

# %% [markdown]
# Read an Image

# %%
image
# Out:
# array([[[ 10,  20,  27],
#         [  8,  18,  25],
#         [  7,  17,  24],
#         ...,
#         [  7,  19,  25],
#         [ 14,  26,  32],
#         [ 20,  32,  38]],
#
#        [[ 18,  28,  35],
#         [ 14,  26,  32],
#         [ 13,  23,  30],
#         ...,
#         [ 17,  29,  35],
#         [ 23,  35,  41],
#         [ 27,  39,  45]],
#
#        [[ 31,  43,  49],
#         [ 27,  41,  47],
#         [ 27,  39,  45],
#         ...,
#         [ 32,  46,  52],
#         [ 37,  51,  57],
#         [ 41,  55,  61]],
#
#        ...,
#
#        [[165, 168, 166],
#         [165, 168, 166],
#         [165, 167, 167],
#         ...,
#         [189, 192, 190],
#         [190, 193, 191],
#         [191, 194, 192]],
#
#        [[166, 169, 167],
#         [166, 169, 167],
#         [166, 168, 168],
#         ...,
#         [189, 192, 190],
#         [190, 193, 191],
#         [191, 194, 192]],
#
#        [[167, 170, 168],
#         [167, 170, 168],
#         [166, 168, 168],
# ...

# %%
image.shape
# Out:
# (1080, 1920, 3)

# %% [markdown]
# Resizing an Image

# %%
# let's downscale the image using new  width and height
down_width = 300
down_height = 200
down_points = (down_width, down_height)
resized_down = cv2.resize(image, down_points, interpolation= cv2.INTER_LINEAR)

# let's upscale the image using new  width and height
up_width = 600
up_height = 400
up_points = (up_width, up_height)
resized_up = cv2.resize(image, up_points, interpolation= cv2.INTER_LINEAR)

# %%
resized_down.shape
# Out:
# (200, 300, 3)

# %%
resized_up.shape
# Out:
# (400, 600, 3)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
gray_image.shape
# Out:
# (1080, 1920)

# %%
import matplotlib.pyplot as plt
plt.imshow(gray_image, cmap='Greys_r')

# %% [markdown]
# Affine Transformation

# %%
import numpy as np
rows, cols = gray_image.shape

# %%
pts1 = np.float32([[50, 50],
                   [200, 50],
                   [50, 200]])

pts2 = np.float32([[10, 100],
                   [200, 50],
                   [100, 250]])

# %%
M = cv2.getAffineTransform(pts1, pts2)
dst = cv2.warpAffine(gray_image, M, (cols, rows))

# %%
plt.imshow(dst, cmap='Greys_r')

# %%
image_180 = cv2.rotate(gray_image, cv2.ROTATE_180)

# %%
plt.imshow(image_180, cmap ="Greys_r")

# %%
import cv2
video = cv2.VideoCapture('video.mp4')

# %%
_,frame0 = video.read()

# %%
frame0 = cv2.cvtColor(frame0,cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt
plt.imshow(frame0)
